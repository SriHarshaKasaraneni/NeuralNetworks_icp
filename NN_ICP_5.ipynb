# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import fashion_mnist
import numpy as np
import matplotlib.pyplot as plt

# Load data
(x_train, _), (x_test, _) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Define autoencoder with an additional hidden layer
encoding_dim = 32  # Compression factor
input_img = Input(shape=(784,))
encoded = Dense(128, activation='relu')(input_img)  # First hidden layer
encoded = Dense(encoding_dim, activation='relu')(encoded)  # Second hidden layer (encoding)
decoded = Dense(128, activation='relu')(encoded)  # First decoding layer
decoded = Dense(784, activation='sigmoid')(decoded)  # Output layer

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')  # Changed optimizer to Adam

# Train autoencoder
history = autoencoder.fit(x_train, x_train,
                          epochs=100,  # Increased epochs
                          batch_size=256,
                          shuffle=True,
                          validation_data=(x_test, x_test))

# Predict and visualize
decoded_imgs = autoencoder.predict(x_test)

# Visualize original and reconstructed images
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Reconstructed
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# Implement a denoising autoencoder
noise_factor = 0.2  # Reduced noise factor
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# Redefine autoencoder for denoising
input_img_noisy = Input(shape=(784,))
encoded_noisy = Dense(128, activation='relu')(input_img_noisy)
encoded_noisy = Dense(encoding_dim, activation='relu')(encoded_noisy)
decoded_noisy = Dense(128, activation='relu')(encoded_noisy)
decoded_noisy = Dense(784, activation='sigmoid')(decoded_noisy)

denoising_autoencoder = Model(input_img_noisy, decoded_noisy)
denoising_autoencoder.compile(optimizer='adam', loss='binary_crossentropy')  # Changed optimizer to Adam

# Train denoising autoencoder
history_denoising = denoising_autoencoder.fit(x_train_noisy, x_train,
                                              epochs=100,  # Increased epochs
                                              batch_size=256,
                                              shuffle=True,
                                              validation_data=(x_test_noisy, x_test))

# Predict and visualize denoised images
denoised_imgs = denoising_autoencoder.predict(x_test_noisy)

plt.figure(figsize=(20, 4))
for i in range(n):
    # Noisy image
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Reconstructed image
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(denoised_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# Plot loss and accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_denoising.history['loss'], label='Denoising Training Loss')
plt.plot(history_denoising.history['val_loss'], label='Denoising Validation Loss')
plt.title('Denoising Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/100
# 235/235 [==============================] - 17s 51ms/step - loss: 0.3709 - val_loss: 0.3145
# Epoch 2/100
# 235/235 [==============================] - 7s 30ms/step - loss: 0.3046 - val_loss: 0.3016
# Epoch 3/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2956 - val_loss: 0.2949
# Epoch 4/100
# 235/235 [==============================] - 7s 29ms/step - loss: 0.2907 - val_loss: 0.2911
# Epoch 5/100
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2878 - val_loss: 0.2890
# Epoch 6/100
# 235/235 [==============================] - 7s 29ms/step - loss: 0.2858 - val_loss: 0.2869
# Epoch 7/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2840 - val_loss: 0.2855
# Epoch 8/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2827 - val_loss: 0.2843
# Epoch 9/100
# 235/235 [==============================] - 6s 26ms/step - loss: 0.2816 - val_loss: 0.2833
# Epoch 10/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2806 - val_loss: 0.2824
# Epoch 11/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2799 - val_loss: 0.2817
# Epoch 12/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2792 - val_loss: 0.2809
# Epoch 13/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2784 - val_loss: 0.2803
# Epoch 14/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2779 - val_loss: 0.2799
# Epoch 15/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2774 - val_loss: 0.2794
# Epoch 16/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2769 - val_loss: 0.2790
# Epoch 17/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2766 - val_loss: 0.2788
# Epoch 18/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2762 - val_loss: 0.2785
# Epoch 19/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2759 - val_loss: 0.2781
# Epoch 20/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2755 - val_loss: 0.2778
# Epoch 21/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2752 - val_loss: 0.2779
# Epoch 22/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2750 - val_loss: 0.2773
# Epoch 23/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2747 - val_loss: 0.2770
# Epoch 24/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2745 - val_loss: 0.2768
# Epoch 25/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2743 - val_loss: 0.2766
# Epoch 26/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2740 - val_loss: 0.2765
# Epoch 27/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2739 - val_loss: 0.2763
# Epoch 28/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2737 - val_loss: 0.2761
# Epoch 29/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2735 - val_loss: 0.2760
# Epoch 30/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2734 - val_loss: 0.2757
# Epoch 31/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2732 - val_loss: 0.2757
# Epoch 32/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2731 - val_loss: 0.2754
# Epoch 33/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2729 - val_loss: 0.2752
# Epoch 34/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2728 - val_loss: 0.2763
# Epoch 35/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2727 - val_loss: 0.2750
# Epoch 36/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2725 - val_loss: 0.2750
# Epoch 37/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2724 - val_loss: 0.2748
# Epoch 38/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2723 - val_loss: 0.2748
# Epoch 39/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2721 - val_loss: 0.2747
# Epoch 40/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2720 - val_loss: 0.2745
# Epoch 41/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2719 - val_loss: 0.2744
# Epoch 42/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2718 - val_loss: 0.2744
# Epoch 43/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2717 - val_loss: 0.2743
# Epoch 44/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2717 - val_loss: 0.2741
# Epoch 45/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2715 - val_loss: 0.2741
# Epoch 46/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2714 - val_loss: 0.2741
# Epoch 47/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2713 - val_loss: 0.2739
# Epoch 48/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2713 - val_loss: 0.2737
# Epoch 49/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2712 - val_loss: 0.2737
# Epoch 50/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2711 - val_loss: 0.2737
# Epoch 51/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2710 - val_loss: 0.2735
# Epoch 52/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2709 - val_loss: 0.2735
# Epoch 53/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2709 - val_loss: 0.2735
# Epoch 54/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2708 - val_loss: 0.2734
# Epoch 55/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2707 - val_loss: 0.2735
# Epoch 56/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2707 - val_loss: 0.2732
# Epoch 57/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2706 - val_loss: 0.2733
# Epoch 58/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2706 - val_loss: 0.2733
# Epoch 59/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2705 - val_loss: 0.2734
# Epoch 60/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2705 - val_loss: 0.2731
# Epoch 61/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2704 - val_loss: 0.2730
# Epoch 62/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2704 - val_loss: 0.2729
# Epoch 63/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2703 - val_loss: 0.2728
# Epoch 64/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2702 - val_loss: 0.2728
# Epoch 65/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2702 - val_loss: 0.2729
# Epoch 66/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2702 - val_loss: 0.2729
# Epoch 67/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2701 - val_loss: 0.2726
# Epoch 68/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2701 - val_loss: 0.2728
# Epoch 69/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2701 - val_loss: 0.2727
# Epoch 70/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2700 - val_loss: 0.2727
# Epoch 71/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2700 - val_loss: 0.2726
# Epoch 72/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2699 - val_loss: 0.2727
# Epoch 73/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2699 - val_loss: 0.2724
# Epoch 74/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2698 - val_loss: 0.2726
# Epoch 75/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2698 - val_loss: 0.2727
# Epoch 76/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2698 - val_loss: 0.2724
# Epoch 77/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2697 - val_loss: 0.2723
# Epoch 78/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2697 - val_loss: 0.2723
# Epoch 79/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2697 - val_loss: 0.2724
# Epoch 80/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2696 - val_loss: 0.2722
# Epoch 81/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2696 - val_loss: 0.2724
# Epoch 82/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2696 - val_loss: 0.2723
# Epoch 83/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2695 - val_loss: 0.2721
# Epoch 84/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2695 - val_loss: 0.2721
# Epoch 85/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2695 - val_loss: 0.2721
# Epoch 86/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2694 - val_loss: 0.2720
# Epoch 87/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2694 - val_loss: 0.2721
# Epoch 88/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2694 - val_loss: 0.2722
# Epoch 89/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2693 - val_loss: 0.2719
# Epoch 90/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2693 - val_loss: 0.2721
# Epoch 91/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2693 - val_loss: 0.2722
# Epoch 92/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2693 - val_loss: 0.2720
# Epoch 93/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2693 - val_loss: 0.2719
# Epoch 94/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2692 - val_loss: 0.2719
# Epoch 95/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2692 - val_loss: 0.2719
# Epoch 96/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2692 - val_loss: 0.2720
# Epoch 97/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2692 - val_loss: 0.2718
# Epoch 98/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2691 - val_loss: 0.2720
# Epoch 99/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2691 - val_loss: 0.2719
# Epoch 100/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2691 - val_loss: 0.2717
# 313/313 [==============================] - 1s 2ms/step
# Epoch 1/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.3746 - val_loss: 0.3206
# Epoch 2/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.3125 - val_loss: 0.3093
# Epoch 3/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.3034 - val_loss: 0.3034
# Epoch 4/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2985 - val_loss: 0.2989
# Epoch 5/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2953 - val_loss: 0.2963
# Epoch 6/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2929 - val_loss: 0.2948
# Epoch 7/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2912 - val_loss: 0.2931
# Epoch 8/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2897 - val_loss: 0.2918
# Epoch 9/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2886 - val_loss: 0.2909
# Epoch 10/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2876 - val_loss: 0.2898
# Epoch 11/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2868 - val_loss: 0.2892
# Epoch 12/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2862 - val_loss: 0.2882
# Epoch 13/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2855 - val_loss: 0.2880
# Epoch 14/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2850 - val_loss: 0.2872
# Epoch 15/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2844 - val_loss: 0.2873
# Epoch 16/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2841 - val_loss: 0.2863
# Epoch 17/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2836 - val_loss: 0.2862
# Epoch 18/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2832 - val_loss: 0.2857
# Epoch 19/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2829 - val_loss: 0.2854
# Epoch 20/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2826 - val_loss: 0.2854
# Epoch 21/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2823 - val_loss: 0.2851
# Epoch 22/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2821 - val_loss: 0.2850
# Epoch 23/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2819 - val_loss: 0.2845
# Epoch 24/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2816 - val_loss: 0.2843
# Epoch 25/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2814 - val_loss: 0.2842
# Epoch 26/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2812 - val_loss: 0.2839
# Epoch 27/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2810 - val_loss: 0.2839
# Epoch 28/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2809 - val_loss: 0.2840
# Epoch 29/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2807 - val_loss: 0.2837
# Epoch 30/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2806 - val_loss: 0.2834
# Epoch 31/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2804 - val_loss: 0.2836
# Epoch 32/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2803 - val_loss: 0.2836
# Epoch 33/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2801 - val_loss: 0.2832
# Epoch 34/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2800 - val_loss: 0.2829
# Epoch 35/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2799 - val_loss: 0.2830
# Epoch 36/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2798 - val_loss: 0.2827
# Epoch 37/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2797 - val_loss: 0.2825
# Epoch 38/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2795 - val_loss: 0.2826
# Epoch 39/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2795 - val_loss: 0.2826
# Epoch 40/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2793 - val_loss: 0.2824
# Epoch 41/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2793 - val_loss: 0.2823
# Epoch 42/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2792 - val_loss: 0.2822
# Epoch 43/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2791 - val_loss: 0.2822
# Epoch 44/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2790 - val_loss: 0.2820
# Epoch 45/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2790 - val_loss: 0.2820
# Epoch 46/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2788 - val_loss: 0.2821
# Epoch 47/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2787 - val_loss: 0.2821
# Epoch 48/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2787 - val_loss: 0.2822
# Epoch 49/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2786 - val_loss: 0.2817
# Epoch 50/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2786 - val_loss: 0.2818
# Epoch 51/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2785 - val_loss: 0.2816
# Epoch 52/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2784 - val_loss: 0.2818
# Epoch 53/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2784 - val_loss: 0.2816
# Epoch 54/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2783 - val_loss: 0.2814
# Epoch 55/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2782 - val_loss: 0.2816
# Epoch 56/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2782 - val_loss: 0.2814
# Epoch 57/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2781 - val_loss: 0.2814
# Epoch 58/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2781 - val_loss: 0.2812
# Epoch 59/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2780 - val_loss: 0.2814
# Epoch 60/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2779 - val_loss: 0.2811
# Epoch 61/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2779 - val_loss: 0.2812
# Epoch 62/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2779 - val_loss: 0.2810
# Epoch 63/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2778 - val_loss: 0.2810
# Epoch 64/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2778 - val_loss: 0.2811
# Epoch 65/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2778 - val_loss: 0.2811
# Epoch 66/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2776 - val_loss: 0.2810
# Epoch 67/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2776 - val_loss: 0.2809
# Epoch 68/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2776 - val_loss: 0.2809
# Epoch 69/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2776 - val_loss: 0.2808
# Epoch 70/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2775 - val_loss: 0.2807
# Epoch 71/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2775 - val_loss: 0.2808
# Epoch 72/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2774 - val_loss: 0.2808
# Epoch 73/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2774 - val_loss: 0.2807
# Epoch 74/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2774 - val_loss: 0.2807
# Epoch 75/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2773 - val_loss: 0.2811
# Epoch 76/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2773 - val_loss: 0.2806
# Epoch 77/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2772 - val_loss: 0.2807
# Epoch 78/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2772 - val_loss: 0.2807
# Epoch 79/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2772 - val_loss: 0.2805
# Epoch 80/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2772 - val_loss: 0.2804
# Epoch 81/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2771 - val_loss: 0.2804
# Epoch 82/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2771 - val_loss: 0.2804
# Epoch 83/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2771 - val_loss: 0.2805
# Epoch 84/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2771 - val_loss: 0.2803
# Epoch 85/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2770 - val_loss: 0.2803
# Epoch 86/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2770 - val_loss: 0.2803
# Epoch 87/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2769 - val_loss: 0.2803
# Epoch 88/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2769 - val_loss: 0.2804
# Epoch 89/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2769 - val_loss: 0.2803
# Epoch 90/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2769 - val_loss: 0.2804
# Epoch 91/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2768 - val_loss: 0.2802
# Epoch 92/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2768 - val_loss: 0.2802
# Epoch 93/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2768 - val_loss: 0.2802
# Epoch 94/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2767 - val_loss: 0.2802
# Epoch 95/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2767 - val_loss: 0.2801
# Epoch 96/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2767 - val_loss: 0.2802
# Epoch 97/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2767 - val_loss: 0.2800
# Epoch 98/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2767 - val_loss: 0.2800
# Epoch 99/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2766 - val_loss: 0.2799
# Epoch 100/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2766 - val_loss: 0.2800
# 313/313 [==============================] - 1s 2ms/step
